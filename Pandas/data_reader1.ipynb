# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")

# %%
# data
data.head(5)
# data.tail(5)
# data["Windows"].head(4)
# Out:
#       Date  Android  Windows    iOS  OS X  Unknown  Linux  Chrome OS  KaiOS  \
# 0  2017-12    39.98    36.07  13.22  5.64     2.64   0.69       0.39   0.00
# 1  2018-01    40.05    36.56  12.90  5.61     2.53   0.66       0.39   0.00
# 2  2018-02    40.11    36.69  13.06  5.45     2.46   0.67       0.44   0.00
# 3  2018-03    39.59    36.51  13.51  5.53     2.82   0.68       0.45   0.01
# 4  2018-04    40.06    36.74  12.59  5.88     2.66   0.77       0.44   0.02
#
#    Samsung  Series 40  Nokia Unknown  Playstation  Tizen  Firefox OS  \
# 0     0.18       0.28           0.15         0.11   0.12        0.24
# 1     0.18       0.26           0.15         0.09   0.11        0.26
# 2     0.15       0.19           0.13         0.09   0.09        0.23
# 3     0.14       0.17           0.12         0.09   0.08        0.07
# 4     0.14       0.18           0.12         0.09   0.09        0.00
#
#    BlackBerry OS  SymbianOS  Xbox  Other
# 0           0.10       0.09  0.04   0.06
# ...

# %%
data_good_android = data[ data["Android"] >= 40]
data_good_android.head(10)
# Out:
#        Date  Android  Windows    iOS  OS X  Unknown  Linux  Chrome OS  KaiOS  \
# 1   2018-01    40.05    36.56  12.90  5.61     2.53   0.66       0.39   0.00
# 2   2018-02    40.11    36.69  13.06  5.45     2.46   0.67       0.44   0.00
# 4   2018-04    40.06    36.74  12.59  5.88     2.66   0.77       0.44   0.02
# 5   2018-05    41.04    36.30  12.43  5.89     2.28   0.74       0.54   0.02
# 6   2018-06    41.70    36.19  12.44  5.66     2.14   0.80       0.34   0.01
# 7   2018-07    42.26    35.93  12.82  5.39     1.94   0.77       0.22   0.01
# 8   2018-08    41.66    35.93  13.50  5.47     1.72   0.77       0.29   0.01
# 9   2018-09    40.85    36.23  13.54  5.95     1.31   0.78       0.47   0.29
# 20  2019-08    40.39    35.01  14.13  5.89     2.75   0.79       0.38   0.30
# 21  2019-09    40.44    35.32  14.29  6.40     1.59   0.80       0.66   0.20
#
#     Samsung  Series 40  Nokia Unknown  Playstation  Tizen  Firefox OS  \
# ...

# %%
data.index
data.set_index("Android")
# To save the change:
# data = data.set_index("Android")
# or
# data.set_index("Android", inplace=True)

data.head()
# Out:
#       Date  Android  Windows    iOS  OS X  Unknown  Linux  Chrome OS  KaiOS  \
# 0  2017-12    39.98    36.07  13.22  5.64     2.64   0.69       0.39   0.00
# 1  2018-01    40.05    36.56  12.90  5.61     2.53   0.66       0.39   0.00
# 2  2018-02    40.11    36.69  13.06  5.45     2.46   0.67       0.44   0.00
# 3  2018-03    39.59    36.51  13.51  5.53     2.82   0.68       0.45   0.01
# 4  2018-04    40.06    36.74  12.59  5.88     2.66   0.77       0.44   0.02
#
#    Samsung  Series 40  Nokia Unknown  Playstation  Tizen  Firefox OS  \
# 0     0.18       0.28           0.15         0.11   0.12        0.24
# 1     0.18       0.26           0.15         0.09   0.11        0.26
# 2     0.15       0.19           0.13         0.09   0.09        0.23
# 3     0.14       0.17           0.12         0.09   0.08        0.07
# 4     0.14       0.18           0.12         0.09   0.09        0.00
#
#    BlackBerry OS  SymbianOS  Xbox  Other
# 0           0.10       0.09  0.04   0.06
# ...

# %%
# data.plot()
data["Windows"].plot()
