# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df["Date"] = pd.to_datetime(df["Date"])
df.set_index("Date", inplace=True)
df_bad_windows = df[df["Windows"] <= 36]

# if there was an unsorted index: 
# df.sort_index(inplace=True)

# if you wanted to make changes to the dateframe without changing the original one, use this:
# new_df = df.copy()

# %%
df_bad_windows.plot()
