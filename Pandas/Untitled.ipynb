# %%
import pandas as pd

# %%
df = pd.read_csv("developer_survey_2019/survey_results_public.csv", index_col="Respondent")

# %%
filt = ( df["DevType"].str.contains("Data scientist or machine learning specialist", na=False) )
df.loc[filt, ["Country", "Hobbyist", "DevType"]].head(20)
# Out:
#                        Country Hobbyist  \
# Respondent
# 6                       Canada      Yes
# 10                       India      Yes
# 12                      Canada       No
# 33                   Argentina       No
# 62                 Netherlands      Yes
# 66                     Germany      Yes
# 97               United States      Yes
# 99                       India      Yes
# 110              United States      Yes
# 129              United States      Yes
# 133              United States      Yes
# 145                      Japan      Yes
# 146              United States      Yes
# 174                      India      Yes
# 184                     Latvia      Yes
# 189         Hong Kong (S.A.R.)      Yes
# 192                     Poland      Yes
# 197                  Australia       No
# 199                Netherlands      Yes
# 202                     Canada      Yes
#
#                                                       DevType
# Respondent
# ...

# %%
df["Hobbyist"].head(50)
# Out:
# Respondent
# 1      Yes
# 2       No
# 3      Yes
# 4       No
# 5      Yes
#       ...
# 96      No
# 97     Yes
# 98     Yes
# 99     Yes
# 100    Yes
# Name: Hobbyist, Length: 100, dtype: object
